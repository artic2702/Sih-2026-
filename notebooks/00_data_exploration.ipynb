# %% [markdown]
# # Data Exploration — SatQuery AI
#
# Use this notebook to explore BigEarthNet, VRSBench, RSVQA, and CDVQA samples:
# band counts, resolutions, label distributions, query/answer length, etc.
# Owner: Person 1, shared with the team.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from src.utils.io_utils import load_config
config = load_config('../configs/config.yaml')
config
